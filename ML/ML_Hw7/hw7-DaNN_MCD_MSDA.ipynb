# %% [markdown]
# # Homework 11 - Transfer Learning (Domain Adversarial Training)
#
# > Author: Arvin Liu (r09922071@ntu.edu.tw)
#
# 若有任何問題，歡迎來信至助教信箱 kafuchino0410@gmail.com

# %% [markdown]
# # Readme
#
#
# 這份作業的任務是Transfer Learning中的Domain Adversarial Training。
#
# <img src="https://i.imgur.com/iMVIxCH.png" width="500px">
#
# > 也就是左下角的那一塊。
#
# ## Scenario and Why Domain Adversarial Training
# 你現在有Source Data + label，其中Source Data和Target Data可能有點關係，所以你想要訓練一個model做在Source Data上並Predict在Target Data上。
#
# 但這樣有什麼樣的問題? 相信大家學過Anomaly Detection就會知道，如果有data是在Source Data沒有出現過的(或稱Abnormal的)，那麼model大部分都會因為不熟悉這個data而可能亂做一發。
#
# 以下我們將model拆成Feature Extractor(上半部)和Classifier(下半部)來作例子:
# <img src="https://i.imgur.com/IL0PxCY.png" width="500px">
#
# 整個Model在學習Source Data的時候，Feature Extrator因為看過很多次Source Data，所以所抽取出來的Feature可能就頗具意義，例如像圖上的藍色Distribution，已經將圖片分成各個Cluster，所以這個時候Classifier就可以依照這個Cluster去預測結果。
#
# 但是在做Target Data的時候，Feature Extractor會沒看過這樣的Data，導致輸出的Target Feature可能不屬於在Source Feature Distribution上，這樣的Feature給Classifier預測結果顯然就不會做得好。
#
# ## Domain Adversarial Training of Nerural Networks (DaNN)
# 基於如此，是不是只要讓Soucre Data和Target Data經過Feature Extractor都在同個Distribution上，就會做得好了呢? 這就是DaNN的主要核心。
#
# <img src="https://i.imgur.com/vrOE5a6.png" width="500px">
#
# 我們追加一個Domain Classifier，在學習的過程中，讓Domain Classifier去判斷經過Feature Extractor後的Feature是源自於哪個domain，讓Feature Extractor學習如何產生Feature以**騙過**Domain Classifier。 持久下來，通常Feature Extractor都會打贏Domain Classifier。(因為Domain Classifier的Input來自於Feature Extractor，而且對Feature Extractor來說Domain&Classification的任務並沒有衝突。)
#
# 如此一來，我們就可以確信不管是哪一個Domain，Feature Extractor都會把它產生在同一個Feature Distribution上。

# %% [markdown]
# # Data Introduce
#
# 這次的任務是Source Data: 真實照片，Target Data: 手畫塗鴉。
#
# 我們必須讓model看過真實照片以及標籤，嘗試去預測手畫塗鴉的標籤為何。
#
# 資料位於[這裡](https://drive.google.com/file/d/1e4CaQ5VUF3F04XRDGXrnRQGogo89TiF8/view?usp=sharing)，以下的code分別為下載和觀看這次的資料大概長甚麼樣子。
#
# 特別注意一點: **這次的source和target data的圖片都是平衡的，你們可以使用這個資訊做其他事情。**

# %%
# # Download dataset
# !gdown --id '1e4CaQ5VUF3F04XRDGXrnRQGogo89TiF8' --output real_or_drawing.zip
# # Unzip the files
# !unzip real_or_drawing.zip

# %%
import matplotlib.pyplot as plt

def no_axis_show(img, title='', cmap=None):
  # imshow, and set the interpolation mode to be "nearest"。
  # fig = plt.imshow(img, interpolation='nearest', cmap=cmap)
  fig = plt.imshow(img, interpolation='bicubic', cmap=cmap)
  # do not show the axis in the images.
  fig.axes.get_xaxis().set_visible(False)
  fig.axes.get_yaxis().set_visible(False)
  plt.title(title)

titles = ['horse', 'bed', 'clock', 'apple', 'cat', 'plane', 'television', 'dog', 'dolphin', 'spider']
plt.figure(figsize=(18, 18))
for i in range(10):
  plt.subplot(1, 10, i+1)
  fig = no_axis_show(plt.imread(f'./real_or_drawing/train_data/{i}/{500*i}.bmp'), title=titles[i])

# %%
plt.figure(figsize=(18, 18))
for i in range(10):
  plt.subplot(1, 10, i+1)
  fig = no_axis_show(plt.imread(f'./real_or_drawing/test_data/0/' + str(i).rjust(5, '0') + '.bmp'))

# %% [markdown]
# # Special Domain Knowledge
#
# 因為大家塗鴉的時候通常只會畫輪廓，我們可以根據這點將source data做點邊緣偵測處理，讓source data更像target data一點。
#
# ## Canny Edge Detection
# 算法這邊不贅述，只教大家怎麼用。若有興趣歡迎參考wiki或[這裡](https://medium.com/@pomelyu5199/canny-edge-detector-%E5%AF%A6%E4%BD%9C-opencv-f7d1a0a57d19)。
#
# cv2.Canny使用非常方便，只需要兩個參數: low_threshold, high_threshold。
#
# ```cv2.Canny(image, low_threshold, high_threshold)```
#
# 簡單來說就是當邊緣值超過high_threshold，我們就確定它是edge。如果只有超過low_threshold，那就先判斷一下再決定是不是edge。
#
# 以下我們直接拿source data做做看。

# %%
import cv2
import matplotlib.pyplot as plt
titles = ['horse', 'bed', 'clock', 'apple', 'cat', 'plane', 'television', 'dog', 'dolphin', 'spider']
plt.figure(figsize=(18, 18))

original_img = plt.imread(f'./real_or_drawing/train_data/0/0.bmp')
plt.subplot(1, 5, 1)
no_axis_show(original_img, title='original')

gray_img = cv2.cvtColor(original_img, cv2.COLOR_RGB2GRAY)
plt.subplot(1, 5, 2)
no_axis_show(gray_img, title='gray scale', cmap='gray')

canny_50100 = cv2.Canny(gray_img, 50, 100)
plt.subplot(1, 5, 3)
no_axis_show(canny_50100, title='Canny(50, 100)', cmap='gray')

canny_150200 = cv2.Canny(gray_img, 150, 200)
plt.subplot(1, 5, 4)
no_axis_show(canny_150200, title='Canny(150, 200)', cmap='gray')

canny_250300 = cv2.Canny(gray_img, 250, 300)
plt.subplot(1, 5, 5)
no_axis_show(canny_250300, title='Canny(250, 300)', cmap='gray')

# %% [markdown]
# # Data Process
#
# 在這裡我故意將data用成可以使用torchvision.ImageFolder的形式，所以只要使用該函式便可以做出一個datasets。
#
# transform的部分請參考以下註解。
# <!--
# #### 一些細節
#
# 在一般的版本上，對灰階圖片使用RandomRotation使用```transforms.RandomRotation(15)```即可。但在colab上需要加上```fill=(0,)```才可運行。
# 在n98上執行需要把```fill=(0,)```拿掉才可運行。 -->

# %%
from tqdm import tqdm
from time import time
import numpy as np
import random
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.autograd import Function
import pandas as pd

import torch.optim as optim
import torchvision.transforms as transforms
from torchvision.datasets import ImageFolder
from torch.utils.data import DataLoader, ConcatDataset, Subset, Dataset
from collections import defaultdict
import matplotlib.pyplot as plt
import cv2

def same_seeds(seed):
    # Python built-in random module
    random.seed(seed)
    # Numpy
    np.random.seed(seed)
    # Torch
    torch.manual_seed(seed)
    if torch.cuda.is_available():
        torch.cuda.manual_seed(seed)
        torch.cuda.manual_seed_all(seed)
    torch.backends.cudnn.benchmark = False
    torch.backends.cudnn.deterministic = True

same_seeds(1173)

source_transform = transforms.Compose([
    # Turn RGB to grayscale. (Bacause Canny do not support RGB images.)
    transforms.Grayscale(),
    transforms.Resize((32, 32)),
    # cv2 do not support skimage.Image, so we transform it to np.array, 
    # and then adopt cv2.Canny algorithm.
    transforms.Lambda(lambda x: cv2.Canny(np.array(x), 170, 300)),
    # Transform np.array back to the skimage.Image.
    transforms.ToPILImage(),
    # 50% Horizontal Flip. (For Augmentation)
    transforms.RandomHorizontalFlip(),
    # Rotate +- 15 degrees. (For Augmentation), and filled with zero 
    # if there's empty pixel after rotation.
    transforms.RandomRotation(15, fill=(0,)),
    # Transform to tensor for model inputs.
    transforms.ToTensor(),
])

source_transform_2 = transforms.Compose([
    # Turn RGB to grayscale. (Bacause Canny do not support RGB images.)
    transforms.Grayscale(),
    transforms.Resize((32, 32)),
    # cv2 do not support skimage.Image, so we transform it to np.array, 
    # and then adopt cv2.Canny algorithm.
    # transforms.Lambda(lambda x: cv2.convertScaleAbs(  cv2.Sobel(np.array(x), cv2.CV_64F, 1, 0) + cv2.Sobel(np.array(x), cv2.CV_64F, 0, 1)  )),
    transforms.Lambda(lambda x: cv2.Canny(np.array(x), 150, 400)),
    # Transform np.array back to the skimage.Image.
    transforms.ToPILImage(),
    # 50% Horizontal Flip. (For Augmentation)
    transforms.RandomHorizontalFlip(),
    # Rotate +- 15 degrees. (For Augmentation), and filled with zero 
    # if there's empty pixel after rotation.
    transforms.RandomRotation(15, fill=(0,)),
    # Transform to tensor for model inputs.
    transforms.ToTensor(),
])

source_transform_3 = transforms.Compose([
    # Turn RGB to grayscale. (Bacause Canny do not support RGB images.)
    transforms.Grayscale(),
    transforms.Resize((32, 32)),
    # cv2 do not support skimage.Image, so we transform it to np.array, 
    # and then adopt cv2.Canny algorithm.
    # transforms.Lambda(lambda x: cv2.convertScaleAbs(  cv2.Sobel(np.array(x), cv2.CV_64F, 1, 0) + cv2.Sobel(np.array(x), cv2.CV_64F, 0, 1)  )),
    transforms.Lambda(lambda x: cv2.Canny(np.array(x), 100, 300)),
    # Transform np.array back to the skimage.Image.
    transforms.ToPILImage(),
    # 50% Horizontal Flip. (For Augmentation)
    transforms.RandomHorizontalFlip(),
    # Rotate +- 15 degrees. (For Augmentation), and filled with zero 
    # if there's empty pixel after rotation.
    transforms.RandomRotation(15, fill=(0,)),
    # Transform to tensor for model inputs.
    transforms.ToTensor(),
])

source_transform_4 = transforms.Compose([
    # Turn RGB to grayscale. (Bacause Canny do not support RGB images.)
    transforms.Grayscale(),
    transforms.Resize((32, 32)),
    # cv2 do not support skimage.Image, so we transform it to np.array, 
    # and then adopt cv2.Canny algorithm.
    # transforms.Lambda(lambda x: cv2.convertScaleAbs(  cv2.Sobel(np.array(x), cv2.CV_64F, 1, 0) + cv2.Sobel(np.array(x), cv2.CV_64F, 0, 1)  )),
    transforms.Lambda(lambda x: cv2.Canny(np.array(x), 50, 150)),
    # Transform np.array back to the skimage.Image.
    transforms.ToPILImage(),
    # 50% Horizontal Flip. (For Augmentation)
    transforms.RandomHorizontalFlip(),
    # Rotate +- 15 degrees. (For Augmentation), and filled with zero 
    # if there's empty pixel after rotation.
    transforms.RandomRotation(15, fill=(0,)),
    # Transform to tensor for model inputs.
    transforms.ToTensor(),
])

target_transform = transforms.Compose([
    # Turn RGB to grayscale.
    transforms.Grayscale(),
    # Resize: size of source data is 32x32, thus we need to 
    #  enlarge the size of target data from 28x28 to 32x32。
    transforms.Resize((32, 32)),
    # 50% Horizontal Flip. (For Augmentation)
    transforms.RandomHorizontalFlip(),
    # Rotate +- 15 degrees. (For Augmentation), and filled with zero 
    # if there's empty pixel after rotation.
    transforms.RandomRotation(15, fill=(0,)),
    # Transform to tensor for model inputs.
    transforms.ToTensor(),
])
# DaNN and MCD dataset and dataloader
source_dataset = ImageFolder('./real_or_drawing/train_data', transform=source_transform)
target_dataset = ImageFolder('./real_or_drawing/test_data', transform=target_transform)

source_dataloader = DataLoader(source_dataset, batch_size=32, shuffle=True)
target_dataloader = DataLoader(target_dataset, batch_size=32, shuffle=True)
test_dataloader = DataLoader(target_dataset, batch_size=128, shuffle=False)

# MSDA dataset
MSDA_source_domain = []
MSDA_source_dataloader_list = []

MSDA_source_dataset_1 = ImageFolder('./real_or_drawing/train_data', transform=source_transform)
MSDA_source_domain.append(MSDA_source_dataset_1)
MSDA_source_dataset_2 = ImageFolder('./real_or_drawing/train_data', transform=source_transform_2)
MSDA_source_domain.append(MSDA_source_dataset_2)
MSDA_source_dataset_3 = ImageFolder('./real_or_drawing/train_data', transform=source_transform_3)
MSDA_source_domain.append(MSDA_source_dataset_3)
MSDA_source_dataset_4 = ImageFolder('./real_or_drawing/train_data', transform=source_transform_4)
MSDA_source_domain.append(MSDA_source_dataset_4)

MSDA_target_dataset = ImageFolder('./real_or_drawing/test_data', transform=target_transform)

# %% [markdown]
# # Model
#
# Feature Extractor: 典型的VGG-like疊法。
#
# Label Predictor / Domain Classifier: MLP到尾。
#
# 相信作業寫到這邊大家對以下的Layer都很熟悉，因此不再贅述。

# %%
class FeatureExtractor(nn.Module):

    def __init__(self):
        super(FeatureExtractor, self).__init__()

        # self.conv = nn.Sequential(
        #     nn.Conv2d(1, 64, 3, 1, 1),
        #     nn.BatchNorm2d(64),
        #     nn.ReLU(),
        #     nn.MaxPool2d(2),

        #     nn.Conv2d(64, 128, 3, 1, 1),
        #     nn.BatchNorm2d(128),
        #     nn.ReLU(),
        #     nn.MaxPool2d(2),

        #     nn.Conv2d(128, 256, 3, 1, 1),
        #     nn.BatchNorm2d(256),
        #     nn.ReLU(),
        #     nn.MaxPool2d(2),

        #     nn.Conv2d(256, 256, 3, 1, 1),
        #     nn.BatchNorm2d(256),
        #     nn.ReLU(),
        #     nn.MaxPool2d(2),

        #     nn.Conv2d(256, 512, 3, 1, 1),
        #     nn.BatchNorm2d(512),
        #     nn.ReLU(),
        #     nn.MaxPool2d(2)
        # )
        self.conv = nn.Sequential(
            nn.Conv2d(1, 64, 3, 1, 1),
            nn.BatchNorm2d(64),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(kernel_size=2, stride=2),

            nn.Conv2d(64, 128, 3, 1, 1),
            nn.BatchNorm2d(128),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(kernel_size=2, stride=2),

            nn.Conv2d(128, 256, 3, 1, 1),
            nn.BatchNorm2d(256),
            nn.ReLU(inplace=True),

            nn.Conv2d(256, 256, 3, 1, 1),
            nn.BatchNorm2d(256),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(kernel_size=2, stride=2),

            nn.Conv2d(256, 512, 3, 1, 1),
            nn.BatchNorm2d(512),
            nn.ReLU(inplace=True),
            
            nn.Conv2d(512, 512, 3, 1, 1),
            nn.BatchNorm2d(512),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(kernel_size=2, stride=2),

            nn.Conv2d(512, 512, 3, 1, 1),
            nn.BatchNorm2d(512),
            nn.ReLU(inplace=True),
            
            nn.Conv2d(512, 512, 3, 1, 1),
            nn.BatchNorm2d(512),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(kernel_size=2, stride=2),
        )
        
    def forward(self, x):
        x = self.conv(x).squeeze()
        return x

class LabelPredictor(nn.Module):

    def __init__(self):
        super(LabelPredictor, self).__init__()

        self.layer = nn.Sequential(
            nn.Linear(512, 512),
            nn.ReLU(),

            nn.Linear(512, 512),
            nn.ReLU(),

            nn.Linear(512, 10),
        )

    def forward(self, h):
        c = self.layer(h)
        return c

class DomainClassifier(nn.Module):

    def __init__(self):
        super(DomainClassifier, self).__init__()

        self.layer = nn.Sequential(
            nn.Linear(512, 512),
            nn.BatchNorm1d(512),
            nn.ReLU(),

            nn.Linear(512, 512),
            nn.BatchNorm1d(512),
            nn.ReLU(),

            # nn.Linear(512, 512),
            # nn.BatchNorm1d(512),
            # nn.ReLU(),

            # nn.Linear(512, 512),
            # nn.BatchNorm1d(512),
            # nn.ReLU(),

            nn.Linear(512, 1),
        )

    def forward(self, h):
        y = self.layer(h)
        return y

class GradReverse(Function):
    def __init__(self , lambd):
        self.lambd = lambd
        return

    def forward(self , x):
        return x.view_as(x)

    def backward(self , grad_output):
        return -self.lambd * grad_output

class Generator(nn.Module):
    def __init__(self):
        super(Generator, self).__init__()
        self.conv = nn.Sequential(
            nn.Conv2d(1, 64, 3, 1, 1),
            nn.BatchNorm2d(64),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(kernel_size=2, stride=2),

            nn.Conv2d(64, 128, 3, 1, 1),
            nn.BatchNorm2d(128),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(kernel_size=2, stride=2),

            nn.Conv2d(128, 256, 3, 1, 1),
            nn.BatchNorm2d(256),
            nn.ReLU(inplace=True),

            nn.Conv2d(256, 256, 3, 1, 1),
            nn.BatchNorm2d(256),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(kernel_size=2, stride=2),

            nn.Conv2d(256, 512, 3, 1, 1),
            nn.BatchNorm2d(512),
            nn.ReLU(inplace=True),
            
            nn.Conv2d(512, 512, 3, 1, 1),
            nn.BatchNorm2d(512),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(kernel_size=2, stride=2),

            nn.Conv2d(512, 512, 3, 1, 1),
            nn.BatchNorm2d(512),
            nn.ReLU(inplace=True),
            
            nn.Conv2d(512, 512, 3, 1, 1),
            nn.BatchNorm2d(512),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(kernel_size=2, stride=2),
        )
    def forward(self, x):
        x = self.conv(x).squeeze()
        return x

class MCD_Classifier(nn.Module):
    def __init__(self):
        
        super(MCD_Classifier , self).__init__()

        self.fc1 = nn.Linear(512 , 512)
        self.bn1 = nn.BatchNorm1d(512)
        self.fc2 = nn.Linear(512 , 256)
        self.bn2 = nn.BatchNorm1d(256)
        self.fc3 = nn.Linear(256 , 10)
        # self.layer = nn.Sequential(
        #     nn.Linear(512, 512),
        #     nn.BatchNorm1d(512),
        #     nn.ReLU(),

        #     nn.Linear(512, 256),
        #     nn.BatchNorm1d(256),
        #     nn.ReLU(),

        #     nn.Linear(256, 10),
        # )

    # def forward(self, h):
    #     c = self.layer(h)
    #     return c
    def set_lambda(self , lambd):
        self.lambd = lambd
        return

    def forward(self , x , reverse = False):
        if (reverse):
            x = grad_reverse(x , self.lambd)
        x = F.relu(self.bn1(self.fc1(x)))
        x = F.relu(self.bn2(self.fc2(x)))
        x = self.fc3(x)
        return x

class MSDA_Classifier(nn.Module):
    def __init__(self):
        
        super(MSDA_Classifier , self).__init__()
        self.layer = nn.Sequential(
            nn.Linear(512, 512),
            nn.BatchNorm1d(512),
            nn.ReLU(),

            nn.Linear(512, 512),
            nn.BatchNorm1d(512),
            nn.ReLU(),

            nn.Linear(512, 10),
        )

    def forward(self, h):
        c = self.layer(h)
        return c
    # def set_lambda(self , lambd):
    # 	self.lambd = lambd
    # 	return

    # def forward(self , x , reverse = False):
    # 	if (reverse):
    # 		x = grad_reverse(x , self.lambd)
    # 	x = F.relu(self.bn1(self.fc1(x)))
    # 	x = self.fc2(x)
    # 	return x

# %% [markdown]
# # Pre-processing
#
# 這裡我們選用Adam來當Optimizer。

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
def grad_reverse(x , lambd = 1.0):
	return GradReverse(lambd)(x)
def discrepancy(output_1 , output_2):
	return torch.mean(torch.abs(F.softmax(output_1 , dim = 1) - F.softmax(output_2 , dim = 1)))

# DaNN
feature_extractor = FeatureExtractor().cuda()
label_predictor = LabelPredictor().cuda()
domain_classifier = DomainClassifier().cuda()

label_predictor.load_state_dict(torch.load("./DaNNmodel/predictor_model.pt"))
feature_extractor.load_state_dict(torch.load("./DaNNmodel/extractor_model.pt"))
domain_classifier.load_state_dict(torch.load("./DaNNmodel/domain_model.pt"))

optimizer_F = optim.Adam(feature_extractor.parameters())
optimizer_C = optim.Adam(label_predictor.parameters())
optimizer_D = optim.Adam(domain_classifier.parameters())
# MCD
generator = Generator().cuda()
classifier_1 = MCD_Classifier().cuda()
classifier_2 = MCD_Classifier().cuda()

generator.load_state_dict(torch.load("./MCDmodel/generator.pt"))
classifier_1.load_state_dict(torch.load("./MCDmodel/classifier_1.pt"))
classifier_2.load_state_dict(torch.load("./MCDmodel/classifier_2.pt"))

optimizer_generator = optim.Adam(generator.parameters())
optimizer_classifier_1 = optim.Adam(classifier_1.parameters())
optimizer_classifier_2 = optim.Adam(classifier_2.parameters())

# MSDA
min_ = float('inf')
BATCH_SIZE = 32
MSDA_generator = Generator().cuda()
MSDA_classifier_1 = MSDA_Classifier().cuda()
MSDA_classifier_2 = MSDA_Classifier().cuda()

MSDA_generator.load_state_dict(torch.load("./MSDAmodel/MSDA_generator.pt"))
MSDA_classifier_1.load_state_dict(torch.load('./MSDAmodel/MSDA_classifier_1.pt'))
MSDA_classifier_2.load_state_dict(torch.load('./MSDAmodel/MSDA_classifier_2.pt'))

optimizer_MSDA_generator = optim.Adam(MSDA_generator.parameters())
optimizer_MSDA_classifier_1 = optim.Adam(MSDA_classifier_1.parameters())
optimizer_MSDA_classifier_2 = optim.Adam(MSDA_classifier_2.parameters())

# MSDA dataloader
for source in MSDA_source_domain:
	# print(source)
	source_dataset_loader = DataLoader(source, batch_size = 32, shuffle=True)
	if len(source_dataset_loader) < min_:
			min_ = len(source_dataset_loader)
	MSDA_source_dataloader_list.append(source_dataset_loader)

MSDA_target_dataloader = DataLoader(MSDA_target_dataset, batch_size=32, shuffle=True)

if len(MSDA_target_dataloader) < min_:
		min_ = len(MSDA_target_dataloader)
		
# loss
class_criterion = nn.CrossEntropyLoss()
domain_criterion = nn.BCEWithLogitsLoss()
L1_loss = nn.L1Loss()
L2_loss = nn.MSELoss()

# %% [markdown]
# ## Pseudo Data

# %%
class PseudoDataset(Dataset):
    def __init__(self, x, y):
        self.x = x
        self.y = y

    def __len__(self):
        return len(self.y)

    def __getitem__(self, id):
        return self.x[id][0], self.y[id]

pseudo_labels_batch_size = 256
def get_pseudo_labels(dataset):
    # This functions generates pseudo-labels of a dataset using given model.
    # It returns an instance of DatasetFolder containing images whose prediction confidences exceed a given threshold.
    # You are NOT allowed to use any models trained on external data for pseudo-labeling.
    device = "cuda" if torch.cuda.is_available() else "cpu"

    # Construct a data loader.
    data_loader = DataLoader(dataset, batch_size=pseudo_labels_batch_size, shuffle=False)

    # Make sure the model is in eval mode.
    label_predictor.eval()
    feature_extractor.eval()
    generator.eval()
    classifier_1.eval()
    classifier_2.eval()
    MSDA_generator.eval()
    MSDA_classifier_1.eval()
    MSDA_classifier_2.eval()

    # Define softmax function.
    softmax = nn.Softmax(dim=-1)

    idx = []
    labels = []
    # Iterate over the dataset by batches.
    # for batch in tqdm(data_loader):
    for i, batch in enumerate(data_loader):
        img, _ = batch

        # Forward the data
        # Using torch.no_grad() accelerates the forward process.
        with torch.no_grad():
            img = img.cuda()

            class_logits = label_predictor(feature_extractor(img))
            DaNN_Label = torch.argmax(class_logits, dim=1)
        # print(DaNN_Label[0])

        with torch.no_grad():
            img = img.cuda()

            feature = generator(img)
            y_1 = classifier_1(feature)
            y_2 = classifier_2(feature)
            y = (y_1 + y_2) / 2
            (_ , MCD_Label) = torch.max(y , dim = 1)

        # print(MCD_Label[0])
        with torch.no_grad():
            img = img.cuda()

            feature = MSDA_generator(img)
            y_1 = MSDA_classifier_1(feature)
            prob_1 = softmax(y_1)
            y_2 = MSDA_classifier_2(feature)
            prob_2 = softmax(y_2)
            probs = (prob_1 + prob_2)
            MSDA_Label = torch.argmax(probs, dim=1)


        # ---------- TODO ----------
        # Filter the data and construct a new dataset.
        for j, x in enumerate(DaNN_Label):
            if DaNN_Label[j] == MCD_Label[j] == MSDA_Label[j]:
                idx.append(i * pseudo_labels_batch_size + j)
                labels.append(int(DaNN_Label[j]))

    # Turn off the eval mode.
    label_predictor.train()
    feature_extractor.train()
    generator.train()
    classifier_1.train()
    classifier_2.train()
    MSDA_generator.train()
    MSDA_classifier_1.train()
    MSDA_classifier_2.train()

    print ("\nNew data: {:5d}\n".format(len(idx)))
    dataset = PseudoDataset(Subset(dataset, idx), labels)
    return dataset

# %% [markdown]
# ## 如何實作DaNN?
#
# 理論上，在原始paper中是加上Gradient Reversal Layer，並將Feature Extractor / Label Predictor / Domain Classifier 一起train，但其實我們也可以交換的train Domain Classfier & Feature Extractor(就像在train GAN的Generator & Discriminator一樣)，這也是可行的。
#
# 在code實現中，我們採取後者的方式。
#
# ## 小提醒
# * 原文中的lambda(控制Domain Adversarial Loss的係數)是有Adaptive的版本，如果有興趣可以參考[原文](https://arxiv.org/pdf/1505.07818.pdf)。
# * 因為我們完全沒有target的label，所以結果如何，只好丟kaggle看看囉:)?

# %% [markdown]
# ## Define Function

# %%
def adaptive_lambda(epoch, num_epochs):
    p = epoch / num_epochs
    # lamb = 2. / (1 + np.exp(-10*p)) - 1
    lamb = np.log(1.02 + 1.7*p)
    return lamb

def euclidean(x1,x2):
	# print( ((x1-x2)**2).sum().sqrt() )
	return ((x1-x2)**2).sum().sqrt()

def k_moment(output_s1, output_s2, output_s3, output_s4, output_t, k):
	output_s1 = (output_s1**k).mean(0)
	output_s2 = (output_s2**k).mean(0)
	output_s3 = (output_s3**k).mean(0)
	output_t = (output_t**k).mean(0)
	return  euclidean(output_s1, output_t) + euclidean(output_s2, output_t) + euclidean(output_s3, output_t)+ \
		euclidean(output_s1, output_s2) + euclidean(output_s2, output_s3) + euclidean(output_s3, output_s1) +\
		euclidean(output_s4, output_s1) + euclidean(output_s4, output_s2) + euclidean(output_s4, output_s2) + \
		euclidean(output_s4, output_t)
# def k_moment(output_s1, output_s2, output_t, k):
# 	output_s1 = (output_s1**k).mean(0)
# 	output_s2 = (output_s2**k).mean(0)
# 	output_t = (output_t**k).mean(0)
# 	# print("output_s1 = ", end="")
# 	# print(output_s1.shape[0], end="")
# 	# print(" output_s2 = ", end="")
# 	# print(output_s2.shape[0], end="")
# 	# print(" output_t = ", end="")
# 	# print(output_t.shape[0])
# 	return  euclidean(output_s1, output_t) + euclidean(output_s2, output_t) + euclidean(output_s1, output_s2)

def msda_regulizer(output_s1, output_s2, output_s3, output_s4, output_t, belta_moment):
	# print('s1:{}, s2:{}, s3:{}, s4:{}'.format(output_s1.shape, output_s2.shape, output_s3.shape, output_t.shape))
	s1_mean = output_s1.mean(0)
	s2_mean = output_s2.mean(0)
	s3_mean = output_s3.mean(0)
	t_mean = output_t.mean(0)
	output_s1 = output_s1 - s1_mean
	output_s2 = output_s2 - s2_mean
	output_s3 = output_s3 - s3_mean
	output_t = output_t - t_mean
	moment1 = euclidean(output_s1, output_t) + euclidean(output_s2, output_t) + euclidean(output_s3, output_t)+\
		euclidean(output_s1, output_s2) + euclidean(output_s2, output_s3) + euclidean(output_s3, output_s1) +\
		euclidean(output_s4, output_s1) + euclidean(output_s4, output_s2) + euclidean(output_s4, output_s2) + \
		euclidean(output_s4, output_t)
	reg_info = moment1
	#print(reg_info)
	for i in range(belta_moment-1):
		reg_info += k_moment(output_s1,output_s2,output_s3, output_s4, output_t,i+2)
	
	return reg_info/6

# def msda_regulizer(output_s1, output_s2, output_t, belta_moment):
# 	s1_mean = output_s1.mean(0)
# 	s2_mean = output_s2.mean(0)
# 	t_mean = output_t.mean(0)
# 	output_s1 = output_s1 - s1_mean
# 	output_s2 = output_s2 - s2_mean
# 	output_t = output_t - t_mean
# 	moment1 = euclidean(output_s1, output_t) + euclidean(output_s2, output_t) + euclidean(output_s1, output_s2)
# 	reg_info = moment1
# 	#print(reg_info)
# 	for i in range(belta_moment-1):
# 		reg_info += k_moment(output_s1,output_s2, output_t, i+2)
# 	return reg_info/6

def feat_all_domain(img_s1, img_s2, img_s3, img_s4, img_t):
    return MSDA_generator(img_s1), MSDA_generator(img_s2), MSDA_generator(img_s3), MSDA_generator(img_s4), MSDA_generator(img_t)
	
# def feat_all_domain(img_s1, img_s2, img_t):
#     return MSDA_generator(img_s1), MSDA_generator(img_s2), MSDA_generator(img_t)

def C1_all_domain(feat1, feat2, feat3, feat4, feat_t):
    return MSDA_classifier_1(feat1), MSDA_classifier_1(feat2), MSDA_classifier_1(feat3), MSDA_classifier_1(feat4), MSDA_classifier_1(feat_t)

def C2_all_domain(feat1, feat2, feat3, feat4, feat_t):
    return MSDA_classifier_2(feat1), MSDA_classifier_2(feat2), MSDA_classifier_2(feat3), MSDA_classifier_2(feat4), MSDA_classifier_2(feat_t) 

def softmax_loss_all_domain(output1, output2, output3, output4, label_s1, label_s2, label_s3, label_s4):
    return class_criterion(output1, label_s1), class_criterion(output2, label_s2), class_criterion(output3, label_s3), class_criterion(output4,label_s4)

# def softmax_loss_all_domain(output1, output2, label_s1, label_s2):
#     return class_criterion(output1, label_s1), class_criterion(output2, label_s2)


def loss_all_domain(img_s1, img_s2, img_s3, img_s4, img_t, label_s1, label_s2, label_s3, label_s4):
	feat_s1, feat_s2, feat_s3, feat_s4, feat_t = feat_all_domain(img_s1, img_s2, img_s3, img_s4, img_t)
	output_s1_c1, output_s2_c1, output_s3_c1, output_s4_c1, output_t_c1 = \
		C1_all_domain(feat_s1, feat_s2, feat_s3, feat_s4, feat_t)
	output_s1_c2, output_s2_c2, output_s3_c2, output_s4_c2, output_t_c2 = \
		C2_all_domain(feat_s1,feat_s2, feat_s3, feat_s4, feat_t)
	loss_msda =  0.0005* msda_regulizer(feat_s1, feat_s2, feat_s3, feat_s4, feat_t, 5)
	loss_s1_c1, loss_s2_c1,loss_s3_c1,loss_s4_c1 =\
		softmax_loss_all_domain(output_s1_c1, output_s2_c1, output_s3_c1,output_s4_c1, label_s1, label_s2, label_s3,label_s4)
	loss_s1_c2, loss_s2_c2,loss_s3_c2,loss_s4_c2 =\
		softmax_loss_all_domain(output_s1_c2, output_s2_c2, output_s3_c2,output_s4_c2, label_s1, label_s2, label_s3,label_s4)
	return  loss_s1_c1, loss_s2_c1,loss_s3_c1,loss_s4_c1, loss_s1_c2, loss_s2_c2,loss_s3_c2,loss_s4_c2, loss_msda
# def loss_all_domain(img_s1, img_s2, img_t, label_s1, label_s2):
#         feat_s1, feat_s2, feat_t = feat_all_domain(img_s1, img_s2, img_t)
#         output_s1_c1, output_s2_c1, output_t_c1 = C1_all_domain(feat_s1, feat_s2, feat_t)
#         output_s1_c2, output_s2_c2, output_t_c2 = C2_all_domain(feat_s1,feat_s2, feat_t)
#         loss_msda =  0.0005* msda_regulizer(feat_s1, feat_s2, feat_t, 5)
#         loss_s1_c1, loss_s2_c1 = softmax_loss_all_domain(output_s1_c1, output_s2_c1, label_s1, label_s2)
#         loss_s1_c2, loss_s2_c2 = softmax_loss_all_domain(output_s1_c2, output_s2_c2, label_s1, label_s2)        
#         return  loss_s1_c1, loss_s2_c1, loss_s1_c2, loss_s2_c2, loss_msda

# %%
def DaNN_train_epoch(source_dataloader, target_dataloader, lamb):
    '''
    Args:
    source_dataloader: source data的dataloader
    target_dataloader: target data的dataloader
    lamb: control the balance of domain adaptatoin and classification.
    '''

    # D loss: Domain Classifier的loss
    # F loss: Feature Extrator & Label Predictor的loss
    running_D_loss, running_F_loss = 0.0, 0.0
    total_hit, total_num = 0.0, 0.0

    # for i, ((source_data, source_label), (target_data, _)) in tqdm(enumerate(zip(source_dataloader, target_dataloader))):
    for i, ((source_data, source_label), (target_data, _)) in enumerate(zip(source_dataloader, target_dataloader)):

        source_data = source_data.cuda()
        source_label = source_label.cuda()
        target_data = target_data.cuda()


        # Mixed the source data and target data, or it'll mislead the running params
        #   of batch_norm. (runnning mean/var of soucre and target data are different.)
        mixed_data = torch.cat([source_data, target_data], dim=0)
        domain_label = torch.zeros([source_data.shape[0] + target_data.shape[0], 1]).cuda()
        # set domain label of source data to be 1.
        domain_label[:source_data.shape[0]] = 1

        # Step 1 : train domain classifier
        feature = feature_extractor(mixed_data)
        # We don't need to train feature extractor in step 1.
        # Thus we detach the feature neuron to avoid backpropgation.
        domain_logits = domain_classifier(feature.detach())
        loss = domain_criterion(domain_logits, domain_label)
        running_D_loss += loss.item()
        loss.backward()
        optimizer_D.step()

        # Step 2 : train feature extractor and label classifier
        class_logits = label_predictor(feature[:source_data.shape[0]])
        domain_logits = domain_classifier(feature)
        # loss = cross entropy of classification - lamb * domain binary cross entropy.
        # The reason why using subtraction is similar to generator loss in disciminator of GAN
        loss = class_criterion(class_logits, source_label) - lamb * domain_criterion(domain_logits, domain_label)
        running_F_loss += loss.item()
        loss.backward()
        optimizer_F.step()
        optimizer_C.step()

        optimizer_D.zero_grad()
        optimizer_F.zero_grad()
        optimizer_C.zero_grad()
        
        total_hit += torch.sum(torch.argmax(class_logits, dim=1) == source_label).item()
        total_num += source_data.shape[0]
        print(i, end='\r')

    return running_D_loss / (i+1), running_F_loss / (i+1), total_hit / total_num

def MCD_train_epoch(epoch, num_epochs, source_dataloader, target_dataloader):
    '''
    Args:
    source_dataloader: source data的dataloader
    target_dataloader: target data的dataloader
    lamb: control the balance of domain adaptatoin and classification.
    '''
    start = time()
    # D loss: Domain Classifier的loss
    # F loss: Feature Extrator & Label Predictor的loss
    running_Step1_loss, running_Step2_loss, running_Step3_loss = 0.0, 0.0, 0.0
    total_hit1, total_hit2, total_num = 0.0, 0.0, 0.0

    # for i, ((source_data, source_label), (target_data, _)) in tqdm(enumerate(zip(source_dataloader, target_dataloader))):
    for i, ((source_data, source_label), (target_data, _)) in enumerate(zip(source_dataloader, target_dataloader)):

        source_data = source_data.cuda()
        source_label = source_label.cuda()
        target_data = target_data.cuda()

        # Step 1
        optimizer_generator.zero_grad()
        optimizer_classifier_1.zero_grad()
        optimizer_classifier_2.zero_grad()

        feature = generator(source_data)
        y_1 = classifier_1(feature)
        y_2 = classifier_2(feature)
        loss = class_criterion(y_1 , source_label) + class_criterion(y_2 , source_label)
        running_Step1_loss += loss.item()

        loss.backward()

        optimizer_generator.step()
        optimizer_classifier_1.step()
        optimizer_classifier_2.step()

        # Step 2
        optimizer_generator.zero_grad()
        optimizer_classifier_1.zero_grad()
        optimizer_classifier_2.zero_grad()

        feature = generator(source_data)
        y_1 = classifier_1(feature)
        y_2 = classifier_2(feature)
        loss_1 = class_criterion(y_1 , source_label) + class_criterion(y_2 , source_label)

        feature = generator(target_data)
        y_1 = classifier_1(feature)
        y_2 = classifier_2(feature)
        loss_2 = discrepancy(y_1 , y_2)

        loss = loss_1 - loss_2
        running_Step2_loss += loss.item()

        loss.backward()

        optimizer_classifier_1.step()
        optimizer_classifier_2.step()
        
        # Step 3
        for k in range(4):
            optimizer_generator.zero_grad()
            feature = generator(target_data)
            y_1 = classifier_1(feature)
            y_2 = classifier_2(feature)
            loss_discrepancy = discrepancy(y_1 , y_2)
            if i == 3:
                    running_Step3_loss += loss_discrepancy.item()

            loss_discrepancy.backward()
            
            optimizer_generator.step()

        if (i < min(len(source_dataloader) , len(target_dataloader)) - 1):
            m = int(50 * (i + 1) / min(len(source_dataloader) , len(target_dataloader)))
            bar = m * '=' + '>' + (49 - m) * ' '
            print('epoch {}/{} [{}]'.format(epoch + 1 , num_epochs , bar) , end = '\r')
        else:
            bar = 50 * '='
            end = time()
            print('epoch {}/{} [{}] ({}s)'.format(epoch+ 1 , num_epochs , bar , int(end - start)))


        feature = generator(source_data)
        y_1 = classifier_1(feature)
        y_2 = classifier_2(feature)
        total_hit1 += torch.sum(torch.argmax(y_1, dim=1) == source_label).item()
        total_hit2 += torch.sum(torch.argmax(y_2, dim=1) == source_label).item()
        total_num += source_data.shape[0]
        # print(i, end='\r')

    return running_Step1_loss / (i+1) , running_Step2_loss / (i+1), running_Step3_loss / (i+1), total_hit1 / total_num, total_hit2 / total_num


def MSDA_train_epoch(epoch, num_epochs, source_dataloader_list, target_dataloader):
    '''
    Args:
    source_dataloader: source data的dataloader
    target_dataloader: target data的dataloader
    lamb: control the balance of domain adaptatoin and classification.
    '''
    start = time()
    running_Step1_loss, running_Step2_loss, running_Step3_loss = 0.0, 0.0, 0.0
    total_hit1, total_hit2, total_num = 0.0, 0.0, 0.0

    source_dataloader_lengths = [len(dataloader) for dataloader in source_dataloader_list]
    target_dataloader_length = len(target_dataloader)
    max_batch_count = min(min(source_dataloader_lengths), target_dataloader_length)

    last_batch_index = max_batch_count - 1

    for batch_index, (src_batch, tar_batch) in enumerate(zip(zip(*source_dataloader_list), target_dataloader)):
        if batch_index != last_batch_index:
            # Step 1
            source_data_1 = 0
            source_label_1 = 0
            source_data_2 = 0
            source_label_2 = 0
            source_data_3 = 0
            source_label_3 = 0
            source_data_4 = 0
            source_label_4 = 0
            # source_data_1, source_label_1 = src_batch[0]
            # source_data_1 = source_data_1.cuda()
            # source_label_1 = source_label_1.cuda()
            # source_data_2, source_label_2 = src_batch[1]
            # source_data_2 = source_data_2.cuda()
            # source_label_2 = source_label_2.cuda()
            target_data, _ = tar_batch
            target_data = target_data.cuda()
            for index, batch in enumerate(src_batch):
                if index == 0:
                    source_data_1, source_label_1 = batch
                    source_data_1 = source_data_1.cuda()
                    source_label_1 = source_label_1.cuda()
                    continue
                elif index == 1:
                    source_data_2, source_label_2 = batch
                    source_data_2 = source_data_2.cuda()
                    source_label_2 = source_label_2.cuda()
                elif index == 2:
                    source_data_3, source_label_3 = batch
                    source_data_3 = source_data_3.cuda()
                    source_label_3 = source_label_3.cuda()
                elif index == 3:
                    source_data_4, source_label_4 = batch
                    source_data_4 = source_data_4.cuda()
                    source_label_4 = source_label_4.cuda()

            optimizer_MSDA_generator.zero_grad()
            optimizer_MSDA_classifier_1.zero_grad()
            optimizer_MSDA_classifier_2.zero_grad()

            loss_s1_c1, loss_s2_c1, loss_s3_c1, loss_s4_c1, loss_s1_c2, loss_s2_c2, loss_s3_c2, loss_s4_c2, loss_msda = loss_all_domain(
                source_data_1, source_data_2, source_data_3, source_data_4, target_data, source_label_1, source_label_2, source_label_3, source_label_4)

            loss_s_c1 = loss_s1_c1 + loss_s2_c1 + loss_s3_c1 + loss_s4_c1
            loss_s_c2 = loss_s1_c2 + loss_s2_c2 + loss_s3_c2 + loss_s4_c2
            loss = loss_s_c1 + loss_s_c2 + loss_msda
            running_Step1_loss += loss.item()

            loss.backward()

            optimizer_MSDA_generator.step()
            optimizer_MSDA_classifier_1.step()
            optimizer_MSDA_classifier_2.step()

            optimizer_MSDA_generator.zero_grad()
            optimizer_MSDA_classifier_1.zero_grad()
            optimizer_MSDA_classifier_2.zero_grad()

            # Step 2
            loss_s1_c1, loss_s2_c1, loss_s3_c1, loss_s4_c1, loss_s1_c2, loss_s2_c2, loss_s3_c2, loss_s4_c2, loss_msda = loss_all_domain(
                source_data_1, source_data_2, source_data_3, source_data_4, target_data, source_label_1, source_label_2, source_label_3, source_label_4)
            
            target_feature = MSDA_generator(target_data)
            output_target_1 = MSDA_classifier_1(target_feature)
            output_target_2 = MSDA_classifier_2(target_feature)
            
            loss_s_c1 = loss_s1_c1 + loss_s2_c1 + loss_s3_c1 + loss_s4_c1
            loss_s_c2 = loss_s1_c2 + loss_s2_c2 + loss_s3_c2 + loss_s4_c2
            # loss_s = loss_s1_c1 + loss_s2_c2 + loss_msda
            loss_s = loss_s_c1 + loss_s_c2 + loss_msda
            loss_discrepancy = discrepancy(output_target_1, output_target_2)
            loss = loss_s - loss_discrepancy
            running_Step2_loss += loss.item()

            loss.backward()

            optimizer_MSDA_classifier_1.step()
            optimizer_MSDA_classifier_2.step()

            optimizer_MSDA_generator.zero_grad()
            optimizer_MSDA_classifier_1.zero_grad()
            optimizer_MSDA_classifier_2.zero_grad()

            # Step 3
            for i in range(4):
                target_feature = MSDA_generator(target_data)
                output_target_1 = MSDA_classifier_1(target_feature)
                output_target_2 = MSDA_classifier_2(target_feature)
                loss_discrepancy = discrepancy(output_target_1, output_target_2)
                if i == 3:
                    running_Step3_loss += loss_discrepancy.item()
                loss_discrepancy.backward()
                optimizer_MSDA_generator.step()
                optimizer_MSDA_generator.zero_grad()
                optimizer_MSDA_classifier_1.zero_grad()
                optimizer_MSDA_classifier_2.zero_grad()

        feature = MSDA_generator(source_data_1)
        y_1 = MSDA_classifier_1(feature)
        y_2 = MSDA_classifier_2(feature)
        total_hit1 += torch.sum(torch.argmax(y_1, dim=1) == source_label_1).item()
        total_hit2 += torch.sum(torch.argmax(y_2, dim=1) == source_label_1).item()
        total_num += source_data_1.shape[0]

        feature = MSDA_generator(source_data_2)
        y_1 = MSDA_classifier_1(feature)
        y_2 = MSDA_classifier_2(feature)
        total_hit1 += torch.sum(torch.argmax(y_1, dim=1) == source_label_2).item()
        total_hit2 += torch.sum(torch.argmax(y_2, dim=1) == source_label_2).item()
        total_num += source_data_2.shape[0]

        if (batch_index < min(len(source_dataloader_list[0]), len(source_dataloader_list[1]) , len(target_dataloader)) - 1):
            m = int(50 * (batch_index + 1) / min(len(source_dataloader_list[0]), len(source_dataloader_list[1]), len(target_dataloader)))
            bar = m * '=' + '>' + (49 - m) * ' '
            print('epoch {}/{} [{}]'.format(epoch + 1 , num_epochs , bar) , end = '\r')
        else:
            bar = 50 * '='
            end = time()
            print('epoch {}/{} [{}] ({}s)'.format(epoch+ 1 , num_epochs , bar , int(end - start)))

    return running_Step1_loss / (batch_index+1) , running_Step2_loss / (batch_index+1), running_Step3_loss / (batch_index+1), total_hit1 / total_num, total_hit2 / total_num

# %% [markdown]
# # Start Training

# %%
# training
num_epochs = 500
# DaNN
label_predictor.train()
feature_extractor.train()
domain_classifier.train()
# MCD
generator.train()
classifier_1.train()
classifier_2.train()
# MSDA
MSDA_generator.train()
MSDA_classifier_1.train()
MSDA_classifier_2.train()


for epoch in range(num_epochs):
    if epoch == 0 or (epoch+1) % 5 == 0 :
        DaNN_result = []
        MCD_result = []
        MSDA_result = []
        ensemble_result = []
        # DaNN
        label_predictor.eval()
        feature_extractor.eval()
        domain_classifier.eval()
        # MCD
        generator.eval()
        classifier_1.eval()
        classifier_2.eval()
        # MSDA
        MSDA_generator.eval()
        MSDA_classifier_1.eval()
        MSDA_classifier_2.eval()

        with torch.no_grad():
            for i, (test_data, _) in enumerate(test_dataloader):
                test_data = test_data.cuda()

                class_logits = label_predictor(feature_extractor(test_data))

                x = torch.argmax(class_logits, dim=1).cpu().detach().numpy()
                DaNN_result.append(x)
            DaNN_result = np.concatenate(DaNN_result)
            df = pd.DataFrame({'id': np.arange(0, len(DaNN_result)), 'label': DaNN_result})
            df.to_csv('./Ensemble_Predict/Ensemble_DaNN_submission-' + str(epoch+1) + '.csv',index=False)


        with torch.no_grad():
            for i, (test_data, _) in enumerate(test_dataloader):
                test_data = test_data.cuda()

                feature = generator(test_data)
                y_1 = classifier_1(feature)
                y_2 = classifier_2(feature)
                y = (y_1 + y_2)

                answer = torch.argmax(y, dim = 1).cpu().detach().numpy()
                MCD_result.append(answer)    
        MCD_result = np.concatenate(MCD_result)
        df = pd.DataFrame({'id': np.arange(0, len(MCD_result)), 'label': MCD_result})
        df.to_csv('./Ensemble_Predict/Ensemble_MCD_submission-' + str(epoch+1) + '.csv',index=False)


        with torch.no_grad():
            for i, (test_data, _) in enumerate(test_dataloader):
                test_data = test_data.cuda()

                feature = MSDA_generator(test_data)
                y_1 = MSDA_classifier_1(feature)
                y_2 = MSDA_classifier_2(feature)
                y = (y_1 + y_2) 
                    
                answer = torch.argmax(y, dim = 1).cpu().detach().numpy()
                MSDA_result.append(answer)
                
        MSDA_result = np.concatenate(MSDA_result)
        df = pd.DataFrame({'id': np.arange(0, len(MSDA_result)), 'label': MSDA_result})
        df.to_csv('./Ensemble_Predict/Ensemble_MSDA_submission-' + str(epoch+1) + '.csv',index=False)

        for i in range(len(MCD_result)):
            # if MSDA_result[i] == DaNN_result[i] or MSDA_result[i] == MCD_result[i]:
            #     ensemble_result.append(MSDA_result[i])
            # elif MSDA_result[i] != DaNN_result[i] and MSDA_result[i] != MCD_result[i] and MCD_result[i] == DaNN_result[i]:
            #     ensemble_result.append(MCD_result[i])
            # else:
            #     ensemble_result.append(MSDA_result[i])

            if DaNN_result[i] == MSDA_result[i] or DaNN_result[i] == MCD_result[i]:
                ensemble_result.append(DaNN_result[i])
            elif DaNN_result[i] != MSDA_result[i] and DaNN_result[i] != MCD_result[i] and MCD_result[i] == MSDA_result[i]:
                ensemble_result.append(MCD_result[i])
            else:
                ensemble_result.append(DaNN_result[i])

        # Generate your submission
        df = pd.DataFrame({'id': np.arange(0, len(ensemble_result)), 'label': ensemble_result})
        df.to_csv('./Ensemble_Predict/DaNN_Base_Ensemble_submission-' + str(epoch+1) + '.csv',index=False)


        ensemble_result = []
        for i in range(len(MCD_result)):
            if MSDA_result[i] == DaNN_result[i] or MSDA_result[i] == MCD_result[i]:
                ensemble_result.append(MSDA_result[i])
            elif MSDA_result[i] != DaNN_result[i] and MSDA_result[i] != MCD_result[i] and MCD_result[i] == DaNN_result[i]:
                ensemble_result.append(MCD_result[i])
            else:
                ensemble_result.append(MSDA_result[i])
        df = pd.DataFrame({'id': np.arange(0, len(ensemble_result)), 'label': ensemble_result})
        df.to_csv('./Ensemble_Predict/MSDA_Base_Ensemble_submission-' + str(epoch+1) + '.csv',index=False)
            
        # DaNN
        label_predictor.train()
        feature_extractor.train()
        domain_classifier.train()
        # MCD
        generator.train()
        classifier_1.train()
        classifier_2.train()
        # MSDA
        MSDA_generator.train()
        MSDA_classifier_1.train()
        MSDA_classifier_2.train()

    # You should chooose lamnda cleverly.
    lamb = adaptive_lambda(epoch, num_epochs)
    
    # Get Pseudo data
    if epoch == 0 or (epoch+1) % 5 == 0:
        pseudo_set = get_pseudo_labels(target_dataset)
        # DaNN and MCD
        concat_dataset = ConcatDataset([source_dataset, pseudo_set])
        source_dataloader = DataLoader(concat_dataset, batch_size=32, shuffle=True, pin_memory=True, drop_last=True)
        # MSDA
        MSDA_source_domain = []
        MSDA_source_dataloader_list = []
        MSDA_concat_datase_1 = ConcatDataset([MSDA_source_dataset_1, pseudo_set])
        MSDA_concat_datase_2 = ConcatDataset([MSDA_source_dataset_2, pseudo_set])
        MSDA_concat_datase_3 = ConcatDataset([MSDA_source_dataset_3, pseudo_set])
        MSDA_concat_datase_4 = ConcatDataset([MSDA_source_dataset_4, pseudo_set])
        MSDA_source_domain.append(MSDA_concat_datase_1)
        MSDA_source_domain.append(MSDA_concat_datase_2)
        MSDA_source_domain.append(MSDA_concat_datase_3)
        MSDA_source_domain.append(MSDA_concat_datase_4)
        for source in MSDA_source_domain:
            source_dataset_loader = DataLoader(source, batch_size = 32, shuffle=True)
            MSDA_source_dataloader_list.append(source_dataset_loader)

    # Training
    train_D_loss, train_F_loss, train_acc = DaNN_train_epoch(source_dataloader, target_dataloader, lamb=lamb)
    print('epoch {:>3d}: train_D_loss: {:6.4f}, train_F_loss: {:6.4f}, acc {:6.4f}'.format(epoch+1, train_D_loss, train_F_loss, train_acc))
    train_Step1_loss, train_Step2_loss, train_Discrepency_loss, trainF1_acc, trainF2_acc = MCD_train_epoch(epoch, num_epochs, source_dataloader, target_dataloader)
    print('epoch {:>3d}: train_Step1_loss: {:6.4f}, train_Step2_loss: {:6.4f}, train_Discrepency_loss: {:6.4f}, F1_acc {:6.4f}, F2_acc {:6.4f}'.format(epoch+1, train_Step1_loss, train_Step2_loss, train_Discrepency_loss, trainF1_acc, trainF2_acc))
    train_Total_loss, train_Step2_loss, train_Discrepency_loss, train_C1_acc, train_C2_acc = MSDA_train_epoch(epoch, num_epochs, MSDA_source_dataloader_list, MSDA_target_dataloader)
    print('epoch {:>3d}: train_Total_loss: {:6.4f}, train_Step2_loss: {:6.4f}, train_Discrepency_loss: {:6.4f}, F1_acc {:6.4f}, F2_acc {:6.4f}'.format(epoch+1, train_Total_loss, train_Step2_loss, train_Discrepency_loss, train_C1_acc, train_C2_acc))

    torch.save(feature_extractor.state_dict(), './Ensemble/extractor_model-ensemble.pt')
    torch.save(label_predictor.state_dict(), './Ensemble/predictor_model-ensemble.pt')
    torch.save(domain_classifier.state_dict(), './Ensemble/domain_model-ensemble.pt')
    torch.save(generator.state_dict() , './Ensemble/generator-ensemble.pt')
    torch.save(classifier_1.state_dict() , './Ensemble/classifier_1-ensemble.pt')
    torch.save(classifier_2.state_dict() , './Ensemble/classifier_2-ensemble.pt')
    torch.save(MSDA_generator.state_dict() , './Ensemble/MSDA_generator-ensemble.pt')
    torch.save(MSDA_classifier_1.state_dict() , './Ensemble/MSDA_classifier_1-ensemble.pt')
    torch.save(MSDA_classifier_2.state_dict() , './Ensemble/MSDA_classifier_2-ensemble.pt')
# Out:
# New data: 45630
#
# epoch   1: train_D_loss: 0.6855, train_F_loss: 0.0034, acc 0.9983
# epoch 1/500 [==================================================] (187s)
# epoch   1: train_Step1_loss: 0.1860, train_Step2_loss: 0.1176, train_Discrepency_loss: 0.0000, F1_acc 0.9934, F2_acc 0.9934
# epoch 1/500 [==================================================] (425s)
# epoch   1: train_Total_loss: 0.3911, train_Step2_loss: 0.2423, train_Discrepency_loss: 0.0034, F1_acc 0.9965, F2_acc 0.9966
# epoch   2: train_D_loss: 0.6794, train_F_loss: -0.0118, acc 0.9989
# epoch 2/500 [==================================================] (191s)
# epoch   2: train_Step1_loss: 0.0896, train_Step2_loss: 0.0428, train_Discrepency_loss: 0.0000, F1_acc 0.9983, F2_acc 0.9983
# epoch 2/500 [==================================================] (428s)
# epoch   2: train_Total_loss: 0.1889, train_Step2_loss: 0.0821, train_Discrepency_loss: 0.0037, F1_acc 0.9990, F2_acc 0.9989
# epoch   3: train_D_loss: 0.6742, train_F_loss: -0.0123, acc 0.9988
# epoch 3/500 [==================================================] (191s)
# epoch   3: train_Step1_loss: 0.0773, train_Step2_loss: 0.0308, train_Discrepency_loss: 0.0000, F1_acc 0.9989, F2_acc 0.9989
# epoch 3/500 [==================================================] (422s)
# epoch   3: train_Total_loss: 0.1576, train_Step2_loss: 0.0577, train_Discrepency_loss: 0.0038, F1_acc 0.9991, F2_acc 0.9991
# epoch   4: train_D_loss: 0.6735, train_F_loss: -0.0143, acc 0.9986
# epoch 4/500 [==================================================] (198s)
# epoch   4: train_Step1_loss: 0.0672, train_Step2_loss: 0.0259, train_Discrepency_loss: 0.0000, F1_acc 0.9989, F2_acc 0.9989
# epoch 4/500 [==================================================] (424s)
# epoch   4: train_Total_loss: 0.1260, train_Step2_loss: 0.0376, train_Discrepency_loss: 0.0035, F1_acc 0.9991, F2_acc 0.9991
#
# New data: 82219
#
# epoch   5: train_D_loss: 0.6900, train_F_loss: -0.0078, acc 0.9968
# epoch 5/500 [==================================================] (330s)
# epoch   5: train_Step1_loss: 0.1330, train_Step2_loss: 0.0764, train_Discrepency_loss: 0.0000, F1_acc 0.9973, F2_acc 0.9972
# epoch 5/500 [==================================================] (741s)
# epoch   5: train_Total_loss: 0.3457, train_Step2_loss: 0.1978, train_Discrepency_loss: 0.0019, F1_acc 0.9985, F2_acc 0.9986
# epoch   6: train_D_loss: 0.6900, train_F_loss: -0.0118, acc 0.9969
# epoch 6/500 [==================================================] (327s)
# epoch   6: train_Step1_loss: 0.1076, train_Step2_loss: 0.0588, train_Discrepency_loss: 0.0000, F1_acc 0.9984, F2_acc 0.9983
# epoch 6/500 [==================================================] (742s)
# epoch   6: train_Total_loss: 0.2261, train_Step2_loss: 0.1083, train_Discrepency_loss: 0.0014, F1_acc 0.9992, F2_acc 0.9992
# epoch   7: train_D_loss: 0.6900, train_F_loss: -0.0199, acc 0.9981
# epoch 7/500 [==================================================] (333s)
# epoch   7: train_Step1_loss: 0.0916, train_Step2_loss: 0.0470, train_Discrepency_loss: 0.0000, F1_acc 0.9988, F2_acc 0.9988
# epoch 7/500 [==================================================] (728s)
# epoch   7: train_Total_loss: 0.1933, train_Step2_loss: 0.0867, train_Discrepency_loss: 0.0013, F1_acc 0.9993, F2_acc 0.9993
# epoch   8: train_D_loss: 0.6899, train_F_loss: -0.0219, acc 0.9979
# epoch 8/500 [==================================================] (330s)
# epoch   8: train_Step1_loss: 0.0812, train_Step2_loss: 0.0390, train_Discrepency_loss: 0.0000, F1_acc 0.9989, F2_acc 0.9990
# epoch 8/500 [==================================================] (739s)
# epoch   8: train_Total_loss: 0.1668, train_Step2_loss: 0.0653, train_Discrepency_loss: 0.0012, F1_acc 0.9994, F2_acc 0.9994
# epoch   9: train_D_loss: 0.6897, train_F_loss: -0.0214, acc 0.9980
# epoch 9/500 [==================================================] (330s)
# epoch   9: train_Step1_loss: 0.0783, train_Step2_loss: 0.0354, train_Discrepency_loss: 0.0000, F1_acc 0.9992, F2_acc 0.9992
# epoch 9/500 [==================================================] (731s)
# epoch   9: train_Total_loss: 0.1484, train_Step2_loss: 0.0540, train_Discrepency_loss: 0.0011, F1_acc 0.9995, F2_acc 0.9995
#
# New data: 88798
#
# epoch  10: train_D_loss: 0.6918, train_F_loss: -0.0116, acc 0.9944
# epoch 10/500 [==================================================] (349s)
# epoch  10: train_Step1_loss: 0.1197, train_Step2_loss: 0.0700, train_Discrepency_loss: 0.0000, F1_acc 0.9979, F2_acc 0.9980
# epoch 10/500 [==================================================] (781s)
# epoch  10: train_Total_loss: 0.3013, train_Step2_loss: 0.1729, train_Discrepency_loss: 0.0011, F1_acc 0.9986, F2_acc 0.9986
# epoch  11: train_D_loss: 0.6920, train_F_loss: -0.0188, acc 0.9950
# epoch 11/500 [==================================================] (347s)
# epoch  11: train_Step1_loss: 0.1056, train_Step2_loss: 0.0600, train_Discrepency_loss: 0.0000, F1_acc 0.9981, F2_acc 0.9981
# epoch 11/500 [==================================================] (773s)
# epoch  11: train_Total_loss: 0.2256, train_Step2_loss: 0.1124, train_Discrepency_loss: 0.0009, F1_acc 0.9993, F2_acc 0.9993
# epoch  12: train_D_loss: 0.6920, train_F_loss: -0.0230, acc 0.9955
# epoch 12/500 [==================================================] (347s)
# epoch  12: train_Step1_loss: 0.0943, train_Step2_loss: 0.0499, train_Discrepency_loss: 0.0000, F1_acc 0.9987, F2_acc 0.9987
# epoch 12/500 [==================================================] (774s)
# epoch  12: train_Total_loss: 0.1960, train_Step2_loss: 0.0903, train_Discrepency_loss: 0.0009, F1_acc 0.9993, F2_acc 0.9993
# epoch  13: train_D_loss: 0.6919, train_F_loss: -0.0183, acc 0.9960
# epoch 13/500 [==================================================] (348s)
# epoch  13: train_Step1_loss: 0.0888, train_Step2_loss: 0.0461, train_Discrepency_loss: 0.0000, F1_acc 0.9991, F2_acc 0.9991
# epoch 13/500 [==================================================] (773s)
# epoch  13: train_Total_loss: 0.1730, train_Step2_loss: 0.0721, train_Discrepency_loss: 0.0008, F1_acc 0.9995, F2_acc 0.9994
# epoch  14: train_D_loss: 0.6917, train_F_loss: -0.0306, acc 0.9965
# epoch 14/500 [==================================================] (349s)
# epoch  14: train_Step1_loss: 0.0832, train_Step2_loss: 0.0424, train_Discrepency_loss: 0.0000, F1_acc 0.9990, F2_acc 0.9991
# epoch 14/500 [==================================================] (773s)
# epoch  14: train_Total_loss: 0.1545, train_Step2_loss: 0.0605, train_Discrepency_loss: 0.0008, F1_acc 0.9995, F2_acc 0.9995
#
# New data: 91733
#
# epoch  15: train_D_loss: 0.6924, train_F_loss: -0.0178, acc 0.9921
# epoch 15/500 [==================================================] (359s)
# epoch  15: train_Step1_loss: 0.1119, train_Step2_loss: 0.0649, train_Discrepency_loss: 0.0000, F1_acc 0.9980, F2_acc 0.9981
# epoch 15/500 [==================================================] (806s)
# epoch  15: train_Total_loss: 0.2713, train_Step2_loss: 0.1531, train_Discrepency_loss: 0.0008, F1_acc 0.9988, F2_acc 0.9989
# epoch  16: train_D_loss: 0.6922, train_F_loss: -0.0259, acc 0.9935
# epoch 16/500 [==================================================] (370s)
# epoch  16: train_Step1_loss: 0.1030, train_Step2_loss: 0.0593, train_Discrepency_loss: 0.0000, F1_acc 0.9983, F2_acc 0.9983
# epoch 16/500 [==================================================] (806s)
# epoch  16: train_Total_loss: 0.2064, train_Step2_loss: 0.0978, train_Discrepency_loss: 0.0007, F1_acc 0.9993, F2_acc 0.9993
# epoch  17: train_D_loss: 0.6923, train_F_loss: -0.0308, acc 0.9943
# epoch 17/500 [==================================================] (368s)
# epoch  17: train_Step1_loss: 0.0923, train_Step2_loss: 0.0490, train_Discrepency_loss: 0.0000, F1_acc 0.9989, F2_acc 0.9989
# epoch 17/500 [==================================================] (814s)
# epoch  17: train_Total_loss: 0.1789, train_Step2_loss: 0.0780, train_Discrepency_loss: 0.0006, F1_acc 0.9994, F2_acc 0.9995
# epoch  18: train_D_loss: 0.6922, train_F_loss: -0.0357, acc 0.9950
# epoch 18/500 [==================================================] (375s)
# epoch  18: train_Step1_loss: 0.0851, train_Step2_loss: 0.0441, train_Discrepency_loss: 0.0000, F1_acc 0.9990, F2_acc 0.9990
# epoch 18/500 [==================================================] (821s)
# epoch  18: train_Total_loss: 0.1609, train_Step2_loss: 0.0664, train_Discrepency_loss: 0.0006, F1_acc 0.9995, F2_acc 0.9995
# epoch  19: train_D_loss: 0.6925, train_F_loss: -0.0354, acc 0.9951
# epoch 19/500 [==================================================] (366s)
# epoch  19: train_Step1_loss: 0.0807, train_Step2_loss: 0.0395, train_Discrepency_loss: 0.0000, F1_acc 0.9992, F2_acc 0.9992
# epoch 19/500 [==================================================] (821s)
# epoch  19: train_Total_loss: 0.2414, train_Step2_loss: 0.1095, train_Discrepency_loss: 0.0008, F1_acc 0.9992, F2_acc 0.9992
#
# New data: 91296
#
# epoch  20: train_D_loss: 0.6925, train_F_loss: -0.0324, acc 0.9926
# epoch 20/500 [==================================================] (367s)
# epoch  20: train_Step1_loss: 0.0912, train_Step2_loss: 0.0506, train_Discrepency_loss: 0.0000, F1_acc 0.9988, F2_acc 0.9988
# epoch 20/500 [==================================================] (818s)
# epoch  20: train_Total_loss: 0.2690, train_Step2_loss: 0.1409, train_Discrepency_loss: 0.0008, F1_acc 0.9991, F2_acc 0.9991
# epoch  21: train_D_loss: 0.6925, train_F_loss: -0.0376, acc 0.9938
# epoch 21/500 [==================================================] (368s)
# epoch  21: train_Step1_loss: 0.0825, train_Step2_loss: 0.0427, train_Discrepency_loss: 0.0000, F1_acc 0.9990, F2_acc 0.9991
# epoch 21/500 [==================================================] (819s)
# epoch  21: train_Total_loss: 0.2126, train_Step2_loss: 0.0984, train_Discrepency_loss: 0.0007, F1_acc 0.9993, F2_acc 0.9993
# epoch  22: train_D_loss: 0.6923, train_F_loss: -0.0407, acc 0.9943
# epoch 22/500 [==================================================] (368s)
# epoch  22: train_Step1_loss: 0.0789, train_Step2_loss: 0.0399, train_Discrepency_loss: 0.0000, F1_acc 0.9991, F2_acc 0.9991
# epoch 22/500 [==================================================] (807s)
# epoch  22: train_Total_loss: 0.1896, train_Step2_loss: 0.0801, train_Discrepency_loss: 0.0006, F1_acc 0.9993, F2_acc 0.9993
# epoch  23: train_D_loss: 0.6922, train_F_loss: -0.0443, acc 0.9945
# epoch 23/500 [==================================================] (368s)
# epoch  23: train_Step1_loss: 0.0729, train_Step2_loss: 0.0353, train_Discrepency_loss: 0.0000, F1_acc 0.9994, F2_acc 0.9993
# epoch 23/500 [==================================================] (819s)
# epoch  23: train_Total_loss: 0.2025, train_Step2_loss: 0.0921, train_Discrepency_loss: 0.0007, F1_acc 0.9989, F2_acc 0.9989
# epoch  24: train_D_loss: 0.6922, train_F_loss: -0.0490, acc 0.9950
# epoch 24/500 [==================================================] (368s)
# epoch  24: train_Step1_loss: 0.0718, train_Step2_loss: 0.0339, train_Discrepency_loss: 0.0000, F1_acc 0.9993, F2_acc 0.9993
# epoch 24/500 [==================================================] (819s)
# epoch  24: train_Total_loss: 0.1561, train_Step2_loss: 0.0594, train_Discrepency_loss: 0.0006, F1_acc 0.9995, F2_acc 0.9995
#
# New data: 90067
#
# epoch  25: train_D_loss: 0.6920, train_F_loss: -0.0428, acc 0.9930
# epoch 25/500 [==================================================] (366s)
# epoch  25: train_Step1_loss: 0.0767, train_Step2_loss: 0.0402, train_Discrepency_loss: 0.0000, F1_acc 0.9991, F2_acc 0.9991
# epoch 25/500 [==================================================] (797s)
# epoch  25: train_Total_loss: 0.2113, train_Step2_loss: 0.1073, train_Discrepency_loss: 0.0007, F1_acc 0.9990, F2_acc 0.9990
# epoch  26: train_D_loss: 0.6920, train_F_loss: -0.0501, acc 0.9942
# epoch 26/500 [==================================================] (373s)
# epoch  26: train_Step1_loss: 0.0724, train_Step2_loss: 0.0356, train_Discrepency_loss: 0.0000, F1_acc 0.9992, F2_acc 0.9992
# epoch 26/500 [==================================================] (814s)
# epoch  26: train_Total_loss: 0.1662, train_Step2_loss: 0.0726, train_Discrepency_loss: 0.0006, F1_acc 0.9993, F2_acc 0.9993
# epoch  27: train_D_loss: 0.6920, train_F_loss: -0.0511, acc 0.9944
# epoch 27/500 [==================================================] (364s)
# epoch  27: train_Step1_loss: 0.0668, train_Step2_loss: 0.0319, train_Discrepency_loss: 0.0000, F1_acc 0.9994, F2_acc 0.9994
# epoch 27/500 [==================================================] (812s)
# epoch  27: train_Total_loss: 0.1569, train_Step2_loss: 0.0651, train_Discrepency_loss: 0.0006, F1_acc 0.9993, F2_acc 0.9993
# epoch  28: train_D_loss: 0.6922, train_F_loss: -0.0592, acc 0.9954
# epoch 28/500 [==================================================] (366s)
# epoch  28: train_Step1_loss: 0.0653, train_Step2_loss: 0.0307, train_Discrepency_loss: 0.0000, F1_acc 0.9993, F2_acc 0.9993
# epoch 28/500 [==================================================] (803s)
# epoch  28: train_Total_loss: 0.1450, train_Step2_loss: 0.0569, train_Discrepency_loss: 0.0006, F1_acc 0.9994, F2_acc 0.9994
# epoch  29: train_D_loss: 0.6922, train_F_loss: -0.0595, acc 0.9951
# epoch 29/500 [==================================================] (368s)
# epoch  29: train_Step1_loss: 0.0592, train_Step2_loss: 0.0263, train_Discrepency_loss: 0.0000, F1_acc 0.9995, F2_acc 0.9995
# epoch 29/500 [==================================================] (813s)
# epoch  29: train_Total_loss: 0.1285, train_Step2_loss: 0.0470, train_Discrepency_loss: 0.0006, F1_acc 0.9995, F2_acc 0.9995
#
# New data: 90742
#
# epoch  30: train_D_loss: 0.6924, train_F_loss: -0.0490, acc 0.9926
# epoch 30/500 [==================================================] (371s)
# epoch  30: train_Step1_loss: 0.0762, train_Step2_loss: 0.0395, train_Discrepency_loss: 0.0000, F1_acc 0.9989, F2_acc 0.9990
# epoch 30/500 [==================================================] (830s)
# epoch  30: train_Total_loss: 0.1977, train_Step2_loss: 0.0991, train_Discrepency_loss: 0.0006, F1_acc 0.9991, F2_acc 0.9991
# epoch  31: train_D_loss: 0.6923, train_F_loss: -0.0605, acc 0.9942
# epoch 31/500 [==================================================] (374s)
# epoch  31: train_Step1_loss: 0.0694, train_Step2_loss: 0.0342, train_Discrepency_loss: 0.0000, F1_acc 0.9993, F2_acc 0.9994
# epoch 31/500 [==================================================] (786s)
# epoch  31: train_Total_loss: 0.1532, train_Step2_loss: 0.0662, train_Discrepency_loss: 0.0005, F1_acc 0.9994, F2_acc 0.9994
# epoch  32: train_D_loss: 0.6923, train_F_loss: -0.0641, acc 0.9943
# epoch 32/500 [==================================================] (298s)
# epoch  32: train_Step1_loss: 0.0642, train_Step2_loss: 0.0307, train_Discrepency_loss: 0.0000, F1_acc 0.9993, F2_acc 0.9993
# epoch 32/500 [==================================================] (656s)
# epoch  32: train_Total_loss: 0.1439, train_Step2_loss: 0.0577, train_Discrepency_loss: 0.0006, F1_acc 0.9994, F2_acc 0.9995
# epoch  33: train_D_loss: 0.6921, train_F_loss: -0.0674, acc 0.9952
# epoch 33/500 [==================================================] (298s)
# epoch  33: train_Step1_loss: 0.0593, train_Step2_loss: 0.0262, train_Discrepency_loss: 0.0000, F1_acc 0.9994, F2_acc 0.9995
# epoch 33/500 [==================================================] (659s)
# epoch  33: train_Total_loss: 0.1313, train_Step2_loss: 0.0495, train_Discrepency_loss: 0.0005, F1_acc 0.9993, F2_acc 0.9993
# epoch  34: train_D_loss: 0.6921, train_F_loss: -0.0718, acc 0.9953
# epoch 34/500 [==================================================] (298s)
# epoch  34: train_Step1_loss: 0.0577, train_Step2_loss: 0.0257, train_Discrepency_loss: 0.0000, F1_acc 0.9996, F2_acc 0.9996
# epoch 34/500 [==================================================] (657s)
# epoch  34: train_Total_loss: 0.1210, train_Step2_loss: 0.0425, train_Discrepency_loss: 0.0005, F1_acc 0.9996, F2_acc 0.9995
#
# New data: 93353
#
# epoch  35: train_D_loss: 0.6926, train_F_loss: -0.0589, acc 0.9914
# epoch 35/500 [==================================================] (306s)
# epoch  35: train_Step1_loss: 0.0809, train_Step2_loss: 0.0448, train_Discrepency_loss: 0.0000, F1_acc 0.9987, F2_acc 0.9988
# epoch 35/500 [==================================================] (674s)
# epoch  35: train_Total_loss: 0.2195, train_Step2_loss: 0.1194, train_Discrepency_loss: 0.0005, F1_acc 0.9989, F2_acc 0.9989
# epoch  36: train_D_loss: 0.6926, train_F_loss: -0.0651, acc 0.9929
# epoch 36/500 [==================================================] (306s)
# epoch  36: train_Step1_loss: 0.0758, train_Step2_loss: 0.0391, train_Discrepency_loss: 0.0000, F1_acc 0.9992, F2_acc 0.9992
# epoch 36/500 [==================================================] (674s)
# epoch  36: train_Total_loss: 0.1662, train_Step2_loss: 0.0766, train_Discrepency_loss: 0.0005, F1_acc 0.9994, F2_acc 0.9994
# epoch  37: train_D_loss: 0.6927, train_F_loss: -0.0721, acc 0.9935
# epoch 37/500 [==================================================] (306s)
# epoch  37: train_Step1_loss: 0.0697, train_Step2_loss: 0.0352, train_Discrepency_loss: 0.0000, F1_acc 0.9992, F2_acc 0.9992
# epoch 37/500 [==================================================] (690s)
# epoch  37: train_Total_loss: 0.1454, train_Step2_loss: 0.0605, train_Discrepency_loss: 0.0004, F1_acc 0.9994, F2_acc 0.9994
# epoch  38: train_D_loss: 0.6927, train_F_loss: -0.0742, acc 0.9938
# epoch 38/500 [==================================================] (307s)
# epoch  38: train_Step1_loss: 0.0636, train_Step2_loss: 0.0312, train_Discrepency_loss: 0.0000, F1_acc 0.9993, F2_acc 0.9994
# epoch 38/500 [==================================================] (684s)
# epoch  38: train_Total_loss: 0.1386, train_Step2_loss: 0.0550, train_Discrepency_loss: 0.0004, F1_acc 0.9993, F2_acc 0.9993
# epoch  39: train_D_loss: 0.6929, train_F_loss: -0.0784, acc 0.9944
# epoch 39/500 [==================================================] (306s)
# epoch  39: train_Step1_loss: 0.0616, train_Step2_loss: 0.0292, train_Discrepency_loss: 0.0000, F1_acc 0.9995, F2_acc 0.9995
# epoch 39/500 [==================================================] (684s)
# epoch  39: train_Total_loss: 0.1283, train_Step2_loss: 0.0495, train_Discrepency_loss: 0.0004, F1_acc 0.9995, F2_acc 0.9994
#
# New data: 94338
#
# epoch  40: train_D_loss: 0.6929, train_F_loss: -0.0716, acc 0.9928
# epoch 40/500 [==================================================] (311s)
# epoch  40: train_Step1_loss: 0.0760, train_Step2_loss: 0.0410, train_Discrepency_loss: 0.0000, F1_acc 0.9990, F2_acc 0.9989
# epoch 40/500 [==================================================] (689s)
# epoch  40: train_Total_loss: 0.1975, train_Step2_loss: 0.0997, train_Discrepency_loss: 0.0004, F1_acc 0.9991, F2_acc 0.9990
# epoch  41: train_D_loss: 0.6929, train_F_loss: -0.0801, acc 0.9937
# epoch 41/500 [==================================================] (311s)
# epoch  41: train_Step1_loss: 0.0670, train_Step2_loss: 0.0330, train_Discrepency_loss: 0.0000, F1_acc 0.9993, F2_acc 0.9993
# epoch 41/500 [==================================================] (689s)
# epoch  41: train_Total_loss: 0.1489, train_Step2_loss: 0.0642, train_Discrepency_loss: 0.0004, F1_acc 0.9994, F2_acc 0.9995
# epoch  42: train_D_loss: 0.6929, train_F_loss: -0.0837, acc 0.9937
# epoch 42/500 [==================================================] (309s)
# epoch  42: train_Step1_loss: 0.0673, train_Step2_loss: 0.0335, train_Discrepency_loss: 0.0000, F1_acc 0.9993, F2_acc 0.9993
# epoch 42/500 [==================================================] (688s)
# epoch  42: train_Total_loss: 0.1299, train_Step2_loss: 0.0520, train_Discrepency_loss: 0.0004, F1_acc 0.9995, F2_acc 0.9995
# epoch  43: train_D_loss: 0.6928, train_F_loss: -0.0864, acc 0.9941
# epoch 43/500 [==================================================] (311s)
# epoch  43: train_Step1_loss: 0.0613, train_Step2_loss: 0.0291, train_Discrepency_loss: 0.0000, F1_acc 0.9994, F2_acc 0.9994
# epoch 43/500 [==================================================] (696s)
# epoch  43: train_Total_loss: 0.1215, train_Step2_loss: 0.0446, train_Discrepency_loss: 0.0003, F1_acc 0.9995, F2_acc 0.9996
# epoch  44: train_D_loss: 0.6926, train_F_loss: -0.0900, acc 0.9946
# epoch 44/500 [==================================================] (312s)
# epoch  44: train_Step1_loss: 0.0591, train_Step2_loss: 0.0266, train_Discrepency_loss: 0.0000, F1_acc 0.9994, F2_acc 0.9994
# epoch 44/500 [==================================================] (690s)
# epoch  44: train_Total_loss: 0.1225, train_Step2_loss: 0.0433, train_Discrepency_loss: 0.0004, F1_acc 0.9996, F2_acc 0.9995
#
# New data: 92673
#
# epoch  45: train_D_loss: 0.6926, train_F_loss: -0.0855, acc 0.9934
# epoch 45/500 [==================================================] (304s)
# epoch  45: train_Step1_loss: 0.0640, train_Step2_loss: 0.0313, train_Discrepency_loss: 0.0000, F1_acc 0.9993, F2_acc 0.9993
# epoch 45/500 [==================================================] (677s)
# epoch  45: train_Total_loss: 0.1537, train_Step2_loss: 0.0710, train_Discrepency_loss: 0.0004, F1_acc 0.9993, F2_acc 0.9993
# epoch  46: train_D_loss: 0.6926, train_F_loss: -0.0937, acc 0.9947
# epoch 46/500 [==================================================] (304s)
# epoch  46: train_Step1_loss: 0.0613, train_Step2_loss: 0.0298, train_Discrepency_loss: 0.0000, F1_acc 0.9993, F2_acc 0.9993
# epoch 46/500 [==================================================] (679s)
# epoch  46: train_Total_loss: 0.1269, train_Step2_loss: 0.0507, train_Discrepency_loss: 0.0004, F1_acc 0.9994, F2_acc 0.9994
# epoch  47: train_D_loss: 0.6925, train_F_loss: -0.0955, acc 0.9947
# epoch 47/500 [==================================================] (306s)
# epoch  47: train_Step1_loss: 0.0556, train_Step2_loss: 0.0253, train_Discrepency_loss: 0.0000, F1_acc 0.9994, F2_acc 0.9994
# epoch 47/500 [==================================================] (677s)
# epoch  47: train_Total_loss: 0.1158, train_Step2_loss: 0.0436, train_Discrepency_loss: 0.0004, F1_acc 0.9996, F2_acc 0.9996
# epoch  48: train_D_loss: 0.6926, train_F_loss: -0.0980, acc 0.9950
# epoch 48/500 [==================================================] (305s)
# epoch  48: train_Step1_loss: 0.0548, train_Step2_loss: 0.0237, train_Discrepency_loss: 0.0000, F1_acc 0.9995, F2_acc 0.9996
# epoch 48/500 [==================================================] (679s)
# epoch  48: train_Total_loss: 0.1076, train_Step2_loss: 0.0390, train_Discrepency_loss: 0.0004, F1_acc 0.9996, F2_acc 0.9996
# epoch  49: train_D_loss: 0.6926, train_F_loss: -0.1036, acc 0.9958
# epoch 49/500 [==================================================] (304s)
# epoch  49: train_Step1_loss: 0.0525, train_Step2_loss: 0.0228, train_Discrepency_loss: 0.0000, F1_acc 0.9996, F2_acc 0.9996
# epoch 49/500 [==================================================] (677s)
# epoch  49: train_Total_loss: 0.1002, train_Step2_loss: 0.0342, train_Discrepency_loss: 0.0004, F1_acc 0.9995, F2_acc 0.9996
#
# New data: 85281
#
# epoch  50: train_D_loss: 0.6908, train_F_loss: -0.1015, acc 0.9947
# epoch 50/500 [==================================================] (281s)
# epoch  50: train_Step1_loss: 0.0537, train_Step2_loss: 0.0254, train_Discrepency_loss: 0.0000, F1_acc 0.9994, F2_acc 0.9994
# epoch 50/500 [==================================================] (627s)
# epoch  50: train_Total_loss: 0.1358, train_Step2_loss: 0.0619, train_Discrepency_loss: 0.0006, F1_acc 0.9992, F2_acc 0.9992
# epoch  51: train_D_loss: 0.6907, train_F_loss: -0.1057, acc 0.9955
# epoch 51/500 [==================================================] (281s)
# epoch  51: train_Step1_loss: 0.0492, train_Step2_loss: 0.0208, train_Discrepency_loss: 0.0000, F1_acc 0.9995, F2_acc 0.9995
# epoch 51/500 [==================================================] (624s)
# epoch  51: train_Total_loss: 0.1029, train_Step2_loss: 0.0388, train_Discrepency_loss: 0.0005, F1_acc 0.9995, F2_acc 0.9995
# epoch  52: train_D_loss: 0.6905, train_F_loss: -0.1082, acc 0.9957
# epoch 52/500 [==================================================] (281s)
# epoch  52: train_Step1_loss: 0.0490, train_Step2_loss: 0.0214, train_Discrepency_loss: 0.0000, F1_acc 0.9996, F2_acc 0.9996
# epoch 52/500 [==================================================] (625s)
# epoch  52: train_Total_loss: 0.0966, train_Step2_loss: 0.0347, train_Discrepency_loss: 0.0005, F1_acc 0.9995, F2_acc 0.9995
# epoch  53: train_D_loss: 0.6903, train_F_loss: -0.1103, acc 0.9960
# epoch 53/500 [==================================================] (280s)
# epoch  53: train_Step1_loss: 0.0424, train_Step2_loss: 0.0157, train_Discrepency_loss: 0.0000, F1_acc 0.9997, F2_acc 0.9996
# epoch 53/500 [==================================================] (629s)
# epoch  53: train_Total_loss: 0.0941, train_Step2_loss: 0.0334, train_Discrepency_loss: 0.0005, F1_acc 0.9996, F2_acc 0.9996
# epoch  54: train_D_loss: 0.6901, train_F_loss: -0.1159, acc 0.9968
# epoch 54/500 [==================================================] (280s)
# epoch  54: train_Step1_loss: 0.0451, train_Step2_loss: 0.0177, train_Discrepency_loss: 0.0000, F1_acc 0.9997, F2_acc 0.9996
# epoch 54/500 [==================================================] (627s)
# epoch  54: train_Total_loss: 0.0876, train_Step2_loss: 0.0288, train_Discrepency_loss: 0.0005, F1_acc 0.9996, F2_acc 0.9996
#
# New data: 88986
#
# epoch  55: train_D_loss: 0.6913, train_F_loss: -0.1094, acc 0.9945
# epoch 55/500 [==================================================] (292s)
# epoch  55: train_Step1_loss: 0.0550, train_Step2_loss: 0.0261, train_Discrepency_loss: 0.0000, F1_acc 0.9994, F2_acc 0.9995
# epoch 55/500 [==================================================] (648s)
# epoch  55: train_Total_loss: 0.1312, train_Step2_loss: 0.0610, train_Discrepency_loss: 0.0006, F1_acc 0.9993, F2_acc 0.9993
# epoch  56: train_D_loss: 0.6911, train_F_loss: -0.1148, acc 0.9953
# epoch 56/500 [==================================================] (292s)
# epoch  56: train_Step1_loss: 0.0513, train_Step2_loss: 0.0235, train_Discrepency_loss: 0.0000, F1_acc 0.9995, F2_acc 0.9995
# epoch 56/500 [==================================================] (648s)
# epoch  56: train_Total_loss: 0.1091, train_Step2_loss: 0.0432, train_Discrepency_loss: 0.0005, F1_acc 0.9994, F2_acc 0.9994
# epoch  57: train_D_loss: 0.6912, train_F_loss: -0.1181, acc 0.9956
# epoch 57/500 [==================================================] (292s)
# epoch  57: train_Step1_loss: 0.0493, train_Step2_loss: 0.0206, train_Discrepency_loss: 0.0000, F1_acc 0.9996, F2_acc 0.9996
# epoch 57/500 [==================================================] (651s)
# epoch  57: train_Total_loss: 0.0923, train_Step2_loss: 0.0334, train_Discrepency_loss: 0.0005, F1_acc 0.9996, F2_acc 0.9996
# epoch  58: train_D_loss: 0.6911, train_F_loss: -0.1211, acc 0.9962
# epoch 58/500 [==================================================] (292s)
# epoch  58: train_Step1_loss: 0.0484, train_Step2_loss: 0.0199, train_Discrepency_loss: 0.0000, F1_acc 0.9997, F2_acc 0.9997
# epoch 58/500 [==================================================] (648s)
# epoch  58: train_Total_loss: 0.0861, train_Step2_loss: 0.0286, train_Discrepency_loss: 0.0005, F1_acc 0.9996, F2_acc 0.9996
# epoch  59: train_D_loss: 0.6911, train_F_loss: -0.1237, acc 0.9963
# epoch 59/500 [==================================================] (292s)
# epoch  59: train_Step1_loss: 0.0440, train_Step2_loss: 0.0176, train_Discrepency_loss: 0.0000, F1_acc 0.9997, F2_acc 0.9997
# epoch 59/500 [==================================================] (648s)
# epoch  59: train_Total_loss: 0.0839, train_Step2_loss: 0.0272, train_Discrepency_loss: 0.0005, F1_acc 0.9996, F2_acc 0.9996
#
# New data: 88355
#
# 831

# %% [markdown]
# # Inference
#
# 就跟前幾次作業一樣。這裡我使用pd來生產csv，因為看起來比較潮(?)
#
# 此外，200 epochs的Accuracy可能會不太穩定，可以多丟幾次或train久一點。

# %%
import pandas as pd

DaNN_result = []
MCD_result = []
MSDA_result = []

# DaNN
label_predictor = LabelPredictor().cuda()
feature_extractor = FeatureExtractor().cuda()
label_predictor.load_state_dict(torch.load("./Ensemble/predictor_model-ensemble.pt"))
feature_extractor.load_state_dict(torch.load("./Ensemble/extractor_model-ensemble.pt"))
label_predictor.eval()
feature_extractor.eval()
# MCD
generator = Generator().cuda()
classifier_1 = Classifier().cuda()
classifier_2 = Classifier().cuda()
generator.load_state_dict(torch.load("./Ensemble/generator-ensemble.pt"))
classifier_1.load_state_dict(torch.load("./Ensemble/classifier_1-ensemble.pt"))
classifier_2.load_state_dict(torch.load("./Ensemble/classifier_2-ensemble.pt"))
generator.eval()
classifier_1.eval()
classifier_2.eval()
# MSDA
MSDA_generator = Generator().cuda()
MSDA_classifier_1 = Classifier().cuda()
MSDA_classifier_2 = Classifier().cuda()
MSDA_generator.load_state_dict(torch.load("./Ensemble/MSDA_generator-ensemble.pt"))
MSDA_classifier_1.load_state_dict(torch.load('./Ensemble/MSDA_classifier_1-ensemble.pt'))
MSDA_classifier_2.load_state_dict(torch.load('./Ensemble/MSDA_classifier_2-ensemble.pt'))
MSDA_generator.eval()
MSDA_classifier_1.eval()
MSDA_classifier_2.eval()



with torch.no_grad():
    for i, (test_data, _) in enumerate(test_dataloader):
        test_data = test_data.cuda()

        class_logits = label_predictor(feature_extractor(test_data))

        x = torch.argmax(class_logits, dim=1).cpu().detach().numpy()
        DaNN_result.append(x)
DaNN_result = np.concatenate(DaNN_result)
df = pd.DataFrame({'id': np.arange(0, len(DaNN_result)), 'label': DaNN_result})
df.to_csv('Ensemble_DaNN_submission.csv',index=False)


with torch.no_grad():
    for i, (test_data, _) in enumerate(test_dataloader):
        test_data = test_data.cuda()

        feature = generator(test_data)
        y_1 = classifier_1(feature)
        y_2 = classifier_2(feature)
        y = (y_1 + y_2)

        answer = torch.argmax(y, dim = 1).cpu().detach().numpy()
        MCD_result.append(answer)    
MCD_result = np.concatenate(MCD_result)
df = pd.DataFrame({'id': np.arange(0, len(MCD_result)), 'label': MCD_result})
df.to_csv('Ensemble_MCD_submission.csv',index=False)


with torch.no_grad():
    for i, (test_data, _) in enumerate(test_dataloader):
        test_data = test_data.cuda()

        feature = MSDA_generator(test_data)
        y_1 = MSDA_classifier_1(feature)
        y_2 = MSDA_classifier_2(feature)
        y = (y_1 + y_2) 
               
        answer = torch.argmax(y, dim = 1).cpu().detach().numpy()
        MSDA_result.append(answer)
        
MSDA_result = np.concatenate(MSDA_result)
df = pd.DataFrame({'id': np.arange(0, len(MSDA_result)), 'label': MSDA_result})
df.to_csv('Ensemble_MSDA_submission.csv',index=False)

# %% [markdown]
# ## Ensemble

# %%
ensemble_result = []
for i in range(len(MCD_result)):
    # if MSDA_result[i] == DaNN_result[i] or MSDA_result[i] == MCD_result[i]:
    #     ensemble_result.append(MSDA_result[i])
    # elif MSDA_result[i] != DaNN_result[i] and MSDA_result[i] != MCD_result[i] and MCD_result[i] == DaNN_result[i]:
    #     ensemble_result.append(MCD_result[i])
    # else:
    #     ensemble_result.append(MSDA_result[i])

    if DaNN_result[i] == MSDA_result[i] or DaNN_result[i] == MCD_result[i]:
        ensemble_result.append(DaNN_result[i])
    elif DaNN_result[i] != MSDA_result[i] and DaNN_result[i] != MCD_result[i] and MCD_result[i] == MSDA_result[i]:
        ensemble_result.append(MCD_result[i])
    else:
        ensemble_result.append(DaNN_result[i])

# Generate your submission
df = pd.DataFrame({'id': np.arange(0, len(ensemble_result)), 'label': ensemble_result})
df.to_csv('Ensemble_submission.csv',index=False)

# %% [markdown]
# # Training Statistics
#
# - Number of parameters:
#   - Feature Extractor: 2, 142, 336
#   - Label Predictor: 530, 442
#   - Domain Classifier: 1, 055, 233
#
# - Simple
#  - Training time on colab: ~ 1 hr
# - Medium
#  - Training time on colab: 2 ~ 4 hr
# - Strong
#  - Training time on colab: 5 ~ 6 hrs
# - Boss
#  - **Unmeasurable**

# %% [markdown]
# # Learning Curve (Strong Baseline)
# * This method is slightly different from colab.
#
# ![Loss Curve](https://i.imgur.com/vIujQyo.png)
#
# # Accuracy Curve (Strong Baseline)
# * Note that you cannot access testing accuracy. But this plot tells you that even though the model overfits the training data, the testing accuracy is still improving, and that's why you need to train more epochs.
#
# ![Acc Curve](https://i.imgur.com/4W1otXG.png)

# %% [markdown]
# # Special Thanks
# 下面是原本台大助教提供的參考作業。
#
# [NTU_r08942071_太神啦 / 組長: 劉正仁同學](https://drive.google.com/open?id=11uNDcz7_eMS8dMQxvnWsbrdguu9k4c-c)
#
# [NTU_r08921a08_CAT / 組長: 廖子毅同學](https://drive.google.com/open?id=1xIkSs8HAShdcfV1E0NEnf4JDbL7POZTf)
